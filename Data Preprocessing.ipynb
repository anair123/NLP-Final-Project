# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import dateutil.parser

# %%
python -m spacy download en
# Out:
#   File "<ipython-input-9-fc4d5d118d23>", line 1
#     python -m spacy download en
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Netflix

# %%
# dictionary of text dates and links
url_dict = {'04/16/2019':'https://www.reuters.com/article/usa-stocks/us-stocks-wall-street-rises-as-netflix-boosts-tech-internet-stocks-idUSL3N1ZF4XW',
            '04/29/2019':'https://www.reuters.com/article/us-television-13reasonswhy/u-s-youth-suicides-up-after-netflix-show-cause-unclear-study-idUSKCN1S5257',
            '04/30/2019':'https://www.reuters.com/article/us-apple-television/in-streaming-wars-apple-says-it-can-coexist-with-netflix-idUSKCN1S730H',
            '05/09/2019':'https://www.reuters.com/article/us-storybots-m-a-netflix/netflix-buys-kids-show-producer-storybots-idUSKCN1SF1ZK',
            '05/15/2019':'https://www.reuters.com/article/us-investment-funds/big-u-s-hedge-funds-regain-ardor-for-faangs-in-first-quarter-filings-idUSKCN1SL2QL',
           '05/28/2019':'https://www.reuters.com/article/usa-abortion-netflix/netflix-to-rethink-investment-in-georgia-if-abortion-law-takes-effect-idUSL2N2340Y9'}

# %%
# extract info from each website and store it in dataframe
df_text = pd.DataFrame(columns = ['Date','Header','Text'])
header = []
text = []
date = []
for key in url_dict:
    page = requests.get(url_dict[key]).text
    soup = BeautifulSoup(page, 'html.parser')
    date.append(datetime.strptime(key, '%m/%d/%Y').date())
    url_header = soup.find('h1').text
    header.append(url_header)
    url_text = soup.find('div', class_ = 'ArticleBodyWrapper').text
    text.append(url_text)
df_text['Date']=date
df_text['Header']=header
df_text['Text']=text

# %%
df_text
# Out:
#          Date                                             Header  \
# 0  2019-04-16  US STOCKS-Wall Street rises as Netflix boosts ...
# 1  2019-04-29  U.S. youth suicides up after Netflix show, cau...
# 2  2019-04-30  In streaming wars, Apple says it can coexist w...
# 3  2019-05-09          Netflix buys kids show producer StoryBots
# 4  2019-05-15  Big U.S. hedge funds regain ardor for FAANGs i...
# 5  2019-05-28  Netflix to 'rethink' investment in Georgia if ...
#
#                                                 Text
# 0  By April Joyner4 Min Read* Netflix jumps after...
# 1  By Reuters Staff3 Min ReadLOS ANGELES (Reuters...
# 2  By Stephen Nellis2 Min ReadFILE PHOTO: Tim Coo...
# 3  By Reuters Staff2 Min ReadThe Netflix logo is ...
# 4  By Jennifer Ablan, Noel Randewich4 Min Read(Re...
# 5  By Reuters Staff3 Min ReadLOS ANGELES, May 28 ...

# %%
# import stock data of netflix
df_stock = pd.read_csv('NFLX.csv', header=0)
df_stock['Date']=df_stock['Date'].apply(lambda x: datetime.strptime(x, '%m/%d/%Y').date())
df_stock.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1  2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2  2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3  2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4  2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
#
#      Volume
# 0  13181000
# 1  17284900
# 2  17948100
# 3  11670000
# 4   9689000

# %%
# Merge two dataframes
df = pd.merge(df_text, df_stock, how='inner', on='Date')
df = df.sort_values('Date')

# %%
# show % change in stock price after news article publish
pct_stock = df['Open'].pct_change()*100
df['% Change in Stock Price'] = pct_stock
pct_volume = df['Volume'].pct_change()*100
df['% Change in Volume'] = pct_volume
df.head()
# Out:
#          Date                                             Header  \
# 0  2019-04-16  US STOCKS-Wall Street rises as Netflix boosts ...
# 1  2019-04-29  U.S. youth suicides up after Netflix show, cau...
# 2  2019-04-30  In streaming wars, Apple says it can coexist w...
# 3  2019-05-09          Netflix buys kids show producer StoryBots
# 4  2019-05-15  Big U.S. hedge funds regain ardor for FAANGs i...
#
#                                                 Text        Open        High  \
# 0  By April Joyner4 Min Read* Netflix jumps after...  355.000000  364.480011
# 1  By Reuters Staff3 Min ReadLOS ANGELES (Reuters...  373.679993  374.579987
# 2  By Stephen Nellis2 Min ReadFILE PHOTO: Tim Coo...  369.559998  374.500000
# 3  By Reuters Staff2 Min ReadThe Netflix logo is ...  360.899994  364.200012
# 4  By Jennifer Ablan, Noel Randewich4 Min Read(Re...  343.339996  356.500000
#
#           Low       Close   Adj Close    Volume  % Change in Stock Price  \
# 0  352.720001  359.459991  359.459991  18740200                      NaN
# 1  369.119995  371.829987  371.829987   3821700                 5.261970
# 2  368.350006  370.540009  370.540009   3870100                -1.102546
# 3  352.750000  362.750000  362.750000   5882600                -2.343328
# 4  341.390015  354.989990  354.989990   6340100                -4.865613
#
#    % Change in Volume
# 0                 NaN
# 1          -79.606941
# 2            1.266452
# 3           52.001240
# 4            7.777173

# %% [markdown]
# # Processing the text

# %%
# import spacy libraries
import spacy
import en_core_web_sm
from  spacy.lang.en.stop_words import STOP_WORDS
nlp = spacy.load('en_core_web_sm')

# %%
text_nlp = nlp(df['Text'][1]) 
# Remove stop words
text_nlp_clean = [word for word in text_nlp if word.is_stop == False]
# Lemmatize words
text_nlp_clean = [word.lemma_ for word in text_nlp_clean]

# %%
import string

text_clean = []
for ind, row in df.iterrows():
    
    # lower casing
    text_lower = row['Text'].lower()
    
    # tokenization
    text_nlp = nlp(row['Text']) 
    
    # remove punctuation and empty space
    text_nlp_clean = [word for word in text_nlp if not word.is_punct | word.is_space]
    
    # Remove stop words
    text_nlp_clean = [word for word in text_nlp_clean if word.is_stop == False]
    
    # Lemmatize tokens
    text_nlp_clean = [word.lemma_ for word in text_nlp_clean]
    
    # add preprocessed text to list
    text_clean.append(text_nlp_clean)

# %%
text_clean
# Out:
# [['April',
#   'Joyner4',
#   'Min',
#   'read',
#   'Netflix',
#   'jump',
#   'raise',
#   'U.S.',
#   'subscription',
#   'rate',
#   'vote',
#   'Brexit',
#   'deal',
#   'briefly',
#   'rattle',
#   'stock',
#   'UnitedHealth',
#   'contribute',
#   'Dow',
#   'rise',
#   'index',
#   'gain',
#   'Dow',
#   '0.55',
#   'pct',
#   'S&P',
#   '0.96',
#   'pct',
#   'Nasdaq',
#   '1.55',
#   'pct',
#   'update',
#   'mid',
#   'afternoon',
#   'change',
#   'byline',
#   'add',
#   'NEW',
#   'YORK',
#   'dateline)NEW',
#   'YORK',
#   'Jan',
#   '15',
#   'Reuters',
#   'U.S.',
#   'stock',
#   'rise',
#   'Tuesday',
#   'technology',
#   'internet',
#   'stock',
#   'gain',
#   'Netflix',
#   'Inc',
#   'plan',
#   'raise',
#   'fee',
#   'U.S.',
#   'subscriber',
#   'hope',
#   'stimulus',
#   'China',
#   'slow',
#   'economy',
#   'foster',
#   'risk',
#   'mood',
#   'investor',
#   'Netflix',
#   'share',
#   'jump',
#   '6.3',
#   'percent',
#   'video',
#   'stream',
#   'company',
#   'say',
#   'raise',
#   'price',
#   'U.S.',
#   'subscriber',
#   'internet',
#   'stock',
#   'include',
#   'share',
#   'Alphabet',
#   'Inc',
#   'Amazon.com',
#   'Inc',
#   'Apple',
#   'Inc',
#   'rise',
#   'follow',
#   'announcement',
#   'S&P',
#   '500',
#   'communication',
#   'service',
#   'index',
#   'include',
#   'Netflix',
#   'Alphabet',
#   'climb',
#   '1.5',
#   'percent',
#   'S&P',
#   '500',
#   'technology',
#   'stock',
#   'advance',
#   '1.4',
#   'percent',
#   'stock',
#   'find',
#   'support',
#   'hint',
#   'chinese',
#   'official',
#   'stimulus',
#   'near',
#   'term',
#   'ease',
#   'concern',
#   'slowdown',
#   'world',
#   'second',
#   'large',
#   'economy',
#   '“We’ve',
#   'good',
#   'news',
#   'today',
#   'overall',
#   'say',
#   'J.J.',
#   'Kinahan',
#   'chief',
#   'market',
#   'strategist',
#   'TD',
#   'Ameritrade',
#   'Chicago',
#   'China',
#   'help',
#   'defuse',
#   'daily',
#   'emotional',
#   'roller',
#   'coaster',
#   'tariff',
#   'Netflix',
#   'think',
#   'raise',
#   'subscription',
#   'price',
#   'good',
#   '”Wall',
#   'Street',
#   'major',
#   'index',
#   'briefly',
#   'pare',
#   'gain',
#   'british',
#   'parliament',
#   'defeat',
#   'Prime',
#   'Minister',
#   'Theresa',
#   'Brexit',
#   'divorce',
#   'deal',
#   'wide',
#   'margin',
#   'rejection',
#   'deal',
#   'lead',
#   'disorderly',
#   'exit',
#   'European',
#   'Union',
#   'reversal',
#   '2016',
#   'decision',
#   'leave',
#   'eu.“a',
#   'Brexit',
#   'headline',
#   'cross',
#   'tape',
#   'knee',
#   'jerk',
#   'reaction',
#   'recover',
#   'outcome',
#   'largely',
#   'price',
#   'say',
#   'Chris',
#   'Zaccarelli',
#   'chief',
#   'investment',
#   'officer',
#   'Independent',
#   'Advisor',
#   'Alliance',
#   'Charlotte',
#   'North',
#   'Carolina',
#   'Dow',
#   'Jones',
#   'Industrial',
#   'Average',
#   'rise',
#   '132.01',
#   'point',
#   '0.55',
#   'percent',
#   '24,041.85',
#   'S&P',
#   '500',
#   'gain',
#   '24.87',
#   'point',
#   '0.96',
#   'percent',
#   '2,607.48',
#   'Nasdaq',
#   'Composite',
#   'add',
#   '107.07',
#   'point',
#   '1.55',
#   'percent',
#   '7,012.99.earlier',
#   'day',
#   'gain',
#   'cap',
#   'disappointing',
#   'earning',
#   'report',
#   'big',
#   'U.S.',
#   'bank',
#   'JPMorgan',
#   'Chase',
#   'Co',
#   'large',
#   'U.S.',
#   'bank',
#   'asset',
#   'miss',
#   'quarterly',
#   'profit',
#   'estimate',
#   'slump',
#   'bond',
#   'trading',
#   'revenue',
#   'Wells',
#   'Fargo',
#   'Co',
#   'say',
#   'loan',
#   'book',
#   'shrank',
#   'quarterly',
#   'revenue',
#   'fall',
#   'major',
#   'business',
#   'JPMorgan',
#   'share',
#   'erase',
#   'early',
#   'loss',
#   '0.8',
#   'percent',
#   'Health',
#   'insurer',
#   'UnitedHealth',
#   'Group',
#   'jump',
#   '3.1',
#   'percent',
#   'gainer',
#   'Dow',
#   'report',
#   'well',
#   'expect',
#   'quarterly',
#   'profit',
#   'analyst',
#   'expect',
#   'S&P',
#   '500',
#   'profit',
#   'grow',
#   '14',
#   'percent',
#   'fourth',
#   'quarter',
#   'low',
#   '20.1',
#   'percent',
#   'growth',
#   'forecast',
#   'October',
#   'accord',
#   'IBES',
#   'datum',
#   'Refinitiv',
#   'advance',
#   'issue',
#   'outnumber',
#   'decline',
#   'one',
#   'NYSE',
#   '1.60-to-1',
#   'ratio',
#   'Nasdaq',
#   '1.71-to-1',
#   'ratio',
#   'favor',
#   'advancer',
#   'S&P',
#   '500',
#   'post',
#   'new',
#   '52-week',
#   'high',
#   'new',
#   'low',
#   'Nasdaq',
#   'Composite',
#   'record',
#   '22',
#   'new',
#   'high',
#   '15',
#   'new',
#   'low',
#   'report',
#   'April',
#   'Joyner',
#   'additional',
#   'reporting',
#   'Sinéad',
#   'Carew',
#   'New',
#   'York',
#   'Medha',
#   'Singh',
#   'Sruthi',
#   'Shankar',
#   'Bengaluru',
#   'editing',
#   'Anil',
#   'D’Silva',
#   'Sonya',
#   'Hepinstall)Our',
#   'Standards',
#   'Thomson',
#   'Reuters',
#   'Trust',
#   'Principles'],
#  ['Reuters',
#   'Staff3',
#   'Min',
#   'ReadLOS',
#   'ANGELES',
#   'Reuters',
#   'Suicides',
#   'young',
#   'Americans',
#   'rise',
#   'nearly',
#   'month',
#   'follow',
#   '2017',
#   'debut',
#   'popular',
#   'Netflix',
#   'television',
#   'drama',
#   'series',
#   '13',
#   'Reasons',
#   'teenage',
#   'girl',
#   'kill',
#   'U.S.',
#   'study',
#   'show',
#   'Monday',
#   'FILE',
#   'PHOTO',
#   '2017',
#   'MTV',
#   'Movie',
#   'TV',
#   'Awards',
#   'Los',
#   'Angeles',
#   'U.S.',
#   '07/05/2017',
#   'Cast',
#   '13',
#   'Reasons',
#   'present',
#   'Year',
#   'REUTERS',
#   'Mario',
#   'Anzuoni',
#   'File',
#   'PhotoThe',
#   'researcher',
#   'say',
#   'study',
#   'limitation',
#   'direct',
#   'causal',
#   'link',
#   '13',
#   'Reasons',
#   'increase',
#   'suicide',
#   'rate',
#   'rule',
#   'factor',
#   'previous',
#   'study',
#   'find',
#   'watch',
#   'program',
#   'associate',
#   'reduce',
#   'risk',
#   'self',
#   'harm',
#   'young',
#   'adult',
#   'rate',
#   'suicide',
#   'April',
#   '2017',
#   '28.9',
#   'percent',
#   'high',
#   'U.S.',
#   'youth',
#   'age',
#   '10',
#   '17',
#   'expect',
#   'base',
#   'suicide',
#   'count',
#   'trend',
#   'observe',
#   'previous',
#   'year',
#   'National',
#   'Institutes',
#   'Health',
#   'support',
#   'NIH',
#   'study',
#   'say',
#   'Monday',
#   'find',
#   'rate',
#   'suicide',
#   '10-',
#   '17-year',
#   'old',
#   'high',
#   'rest',
#   'year',
#   'result',
#   'additional',
#   'estimate',
#   '195',
#   'suicide',
#   'death',
#   'April',
#   'December',
#   '2017',
#   'versus',
#   'expectation',
#   'base',
#   'past',
#   'datum',
#   'increase',
#   'drive',
#   'primarily',
#   'young',
#   'boy',
#   'say',
#   'Netflix',
#   'spokesman',
#   'say',
#   'company',
#   'see',
#   'study',
#   'review',
#   '“It',
#   'critically',
#   'important',
#   'topic',
#   'work',
#   'hard',
#   'ensure',
#   'handle',
#   'sensitive',
#   'issue',
#   'responsibly',
#   'Netflix',
#   'spokesman',
#   'say',
#   'spokesman',
#   'say',
#   'research',
#   'conflict',
#   'recent',
#   'finding',
#   'team',
#   'University',
#   'Pennsylvania',
#   'survey',
#   '18-',
#   '29-year',
#   'old',
#   'Pennsylvania',
#   'researcher',
#   'find',
#   'student',
#   'watch',
#   'season',
#   '13',
#   'Reasons',
#   'likely',
#   'report',
#   'self',
#   'harm',
#   'suicidal',
#   'thought',
#   'watch',
#   'series',
#   'tell',
#   'story',
#   'teen',
#   'leave',
#   'series',
#   '13',
#   'tape',
#   'describe',
#   'decide',
#   'life',
#   'season',
#   'final',
#   'episode',
#   'depict',
#   'slit',
#   'wrist',
#   'bathtub',
#   'graphic',
#   'scene',
#   'cause',
#   'backlash',
#   'parent',
#   'health',
#   'professional',
#   'prompt',
#   'Netflix',
#   '2017',
#   'additional',
#   'viewer',
#   'warning',
#   'direct',
#   'viewer',
#   'support',
#   'group',
#   'second',
#   'season',
#   'release',
#   '2018',
#   'season',
#   'order',
#   'Netflix',
#   'Chief',
#   'Executive',
#   'Reed',
#   'Hastings',
#   'defend',
#   'season',
#   'renewal',
#   'shareholder',
#   'meeting',
#   'June',
#   '2018.“‘13',
#   'Reasons',
#   'enormously',
#   'popular',
#   'successful',
#   'engage',
#   'content',
#   'controversial',
#   'watch',
#   'Hastings',
#   'say',
#   'NIH',
#   'back',
#   'researcher',
#   'say',
#   'finding',
#   'serve',
#   'reminder',
#   'mindful',
#   'possible',
#   'unintended',
#   'impact',
#   'portrayal',
#   'suicide',
#   'entertainment',
#   'industry',
#   'medium',
#   'use',
#   'good',
#   'practice',
#   'engage',
#   'topic',
#   '”the',
#   'study',
#   'conduct',
#   'university',
#   'hospital',
#   'National',
#   'Institute',
#   'Mental',
#   'Health',
#   'NIMH',
#   'U.S.',
#   'government',
#   'National',
#   'Institutes',
#   'Health',
#   'NIMH',
#   'fund',
#   'study',
#   'report',
#   'Jill',
#   'Serjeant',
#   'Lisa',
#   'Richwine',
#   'editing',
#   'Tom',
#   'Brown',
#   'Rosalba',
#   'O’BrienOur',
#   'Standards',
#   'Thomson',
#   'Reuters',
#   'Trust',
#   'Principles'],
#  ['Stephen',
#   'Nellis2',
#   'Min',
#   'ReadFILE',
#   'PHOTO',
#   'Tim',
#   'Cook',
#   'CEO',
#   'Apple',
#   'speak',
#   'Apple',
#   'special',
#   'event',
#   'Steve',
#   'Jobs',
#   'Theater',
#   'Cupertino',
#   'California',
#   'U.S.',
#   'March',
#   '25',
#   '2019',
#   'REUTERS',
#   'Stephen',
#   'Lam(Reuters',
#   'far',
#   'Netflix',
#   'Inc',
#   'killer',
#   'Apple',
#   'Inc',
#   'envision',
#   'forthcoming',
#   'Apple',
#   'TV+',
#   'streaming',
#   'service',
#   'sit',
#   'alongside',
#   'service',
#   'viewer',
#   'buy',
#   'Apple',
#   'Chief',
#   'Executive',
#   'Tim',
#   'Cook',
#   'say',
#   'Tuesday',
#   'Apple',
#   'March',
#   'say',
#   'launch',
#   'streaming',
#   'service',
#   'original',
#   'content',
#   'big',
#   'name',
#   'include',
#   'Oprah',
#   'Winfrey',
#   'Steven',
#   'Spielberg',
#   'plan',
#   'spend',
#   '$',
#   '2',
#   'billion',
#   'programming',
#   'say',
#   'service',
#   'cost',
#   'investor',
#   'keep',
#   'close',
#   'eye',
#   'Apple',
#   'television',
#   'effort',
#   'subscription',
#   'service',
#   'increasingly',
#   'important',
#   'financial',
#   'result',
#   'iPhone',
#   'sale',
#   'decline',
#   'Apple',
#   'enter',
#   'crowd',
#   'field',
#   'include',
#   'Walt',
#   'Disney',
#   'Co',
#   '$',
#   '6.99',
#   'month',
#   'service',
#   'launch',
#   'fall',
#   'end',
#   'price',
#   'spectrum',
#   'Alphabet',
#   'Inc',
#   'YouTube',
#   'month',
#   'say',
#   'raise',
#   'price',
#   'YouTube',
#   'TV',
#   'online',
#   'service',
#   'cable',
#   'like',
#   'bundle',
#   '70',
#   'channel',
#   '$',
#   '49.99',
#   'month',
#   'conference',
#   'investor',
#   'Tuesday',
#   'Cook',
#   'indicate',
#   'Apple',
#   'try',
#   'viewer',
#   'want',
#   '“There',
#   'huge',
#   'cable',
#   'bundle',
#   'Cook',
#   'tell',
#   'investor',
#   'Tuesday',
#   'refer',
#   'stream',
#   'television',
#   'service',
#   'deliver',
#   'internet',
#   'traditional',
#   'cable',
#   'service',
#   '“We',
#   'think',
#   'user',
#   'go',
#   'multiple',
#   'product',
#   'go',
#   'good',
#   'convince',
#   'Apple',
#   'TV+',
#   'product',
#   '”reporte',
#   'Stephen',
#   'Nellis',
#   'editing',
#   'Lisa',
#   'ShumakerOur',
#   'Standards',
#   'Thomson',
#   'Reuters',
#   'Trust',
#   'Principles'],
#  ['Reuters',
#   'Staff2',
#   'Min',
#   'ReadThe',
#   'Netflix',
#   'logo',
#   'show',
#   'ipad',
#   'Encinitas',
#   'California',
#   'April',
#   '19,2013',
#   'Netflix',
#   'Inc',
#   'report',
#   'April',
#   '22',
#   '2013',
#   'quarter',
#   'profit',
#   'beat',
#   'Wall',
#   'Street',
#   'expectation',
#   'dominant',
#   'video',
#   'rental',
#   'service',
#   'add',
#   'new',
#   'streaming',
#   'subscriber',
#   'United',
#   'States',
#   'Netflix',
#   'share',
#   'soar',
#   '$',
#   '207.39',
#   'hour',
#   'trading',
#   'rise',
#   '19',
#   'percent',
#   'close',
#   '$',
#   '174.37',
#   'Nasdaq',
#   'January',
#   'March',
#   'Netflix',
#   'record',
#   '$',
#   '19',
#   'million',
#   'net',
#   'income',
#   'exclude',
#   'loss',
#   'retire',
#   'debt',
#   'adjust',
#   'earning',
#   'share',
#   '31',
#   'cent',
#   'picture',
#   'take',
#   'April',
#   '19',
#   '2013',
#   'REUTERS',
#   'Mike',
#   'Blake',
#   'UNITED',
#   'STATES)(Reuters',
#   'Netflix',
#   'Inc',
#   'say',
#   'Thursday',
#   'acquire',
#   'StoryBots',
#   'know',
#   'ask',
#   'StoryBots',
#   'series',
#   'look',
#   'show',
#   'child',
#   'ahead',
#   'launch',
#   'Walt',
#   'Disney',
#   'Co',
#   'streaming',
#   'service',
#   'later',
#   'year',
#   'Disney',
#   'new',
#   'family',
#   'friendly',
#   'streaming',
#   'service',
#   'Disney+',
#   'expect',
#   'launch',
#   'November',
#   '12',
#   'feature',
#   'programming',
#   'Marvel',
#   'superhero',
#   'universe',
#   'Star',
#   'Wars',
#   'galaxy',
#   'Toy',
#   'Story',
#   'creator',
#   'Pixar',
#   'animation',
#   'National',
#   'Geographic',
#   'channel',
#   'entire',
#   'library',
#   'Simpsons',
#   '”storybot',
#   'bag',
#   'Emmy',
#   'award',
#   'found',
#   'brother',
#   'Gregg',
#   'Evan',
#   'Spiridellis',
#   'create',
#   'entertainment',
#   'studio',
#   'JibJab',
#   'Media',
#   'Inc',
#   'term',
#   'transaction',
#   'disclose',
#   'second',
#   'content',
#   'company',
#   'acquisition',
#   'stream',
#   'giant',
#   'comic_strip',
#   'publisher',
#   'Millarworld',
#   '2017',
#   'company',
#   'continue',
#   'spend',
#   'billion',
#   'hook',
#   'new',
#   'customer',
#   'build',
#   'library',
#   'original',
#   'series',
#   'film',
#   'Netflix',
#   'buy',
#   'ABQ',
#   'Studios',
#   'year',
#   'purchase',
#   'Millarworld',
#   'bring',
#   'board',
#   'renowned',
#   'comic',
#   'book',
#   'writer',
#   'Mark',
#   'Millar',
#   'host',
#   'character',
#   'franchise',
#   'Netflix',
#   'November',
#   'sign',
#   'agreement',
#   'Roald',
#   'Dahl',
#   'Story',
#   'Co',
#   'say',
#   'adapt',
#   'celebrate',
#   'british',
#   'child',
#   'author',
#   'Roald',
#   'Dahl',
#   'book',
#   'Charlie',
#   'Chocolate',
#   'Factory',
#   'Matilda',
#   'animation',
#   'series',
#   'report',
#   'Akanksha',
#   'Rana',
#   'Vibhuti',
#   'Sharma',
#   'Bengaluru',
#   'editing',
#   'Shailesh',
#   'KuberOur',
#   'Standards',
#   'Thomson',
#   'Reuters',
#   'Trust',
#   'Principles'],
#  ['Jennifer',
#   'Ablan',
#   'Noel',
#   'Randewich4',
#   'Min',
#   'Read(Reuters',
#   'big',
#   'high',
#   'profile',
#   'U.S.',
#   'hedge',
#   'fund',
#   'investor',
#   'money',
#   'manager',
#   'fall',
#   'love',
#   'FAANGs',
#   'quarter',
#   'accord',
#   'regulatory',
#   'filing',
#   'release',
#   'Wednesday',
#   'Facebook',
#   'Amazon',
#   'Netflix',
#   'Google',
#   'logo',
#   'see',
#   'combination',
#   'photo',
#   'Reuters',
#   'file',
#   'REUTERS',
#   'File',
#   'PhotosAfter',
#   'dump',
#   'share',
#   'Facebook',
#   'Inc',
#   'Apple',
#   'Inc',
#   'Amazon.com',
#   'Inc',
#   'Netflix',
#   'Inc',
#   'Alphabet',
#   'Inc',
#   'FAANG',
#   'component',
#   'prominent',
#   'hedge',
#   'fund',
#   'manager',
#   'include',
#   'Tiger',
#   'Global',
#   'Management',
#   'LLC',
#   'move',
#   'popular',
#   'group',
#   'Tiger',
#   'manage',
#   'Chase',
#   'Coleman',
#   'boost',
#   'Facebook',
#   'stake',
#   '64.5',
#   '8.8',
#   'million',
#   'class',
#   'share',
#   'quarter',
#   'accord',
#   'filing',
#   'Securities',
#   'Exchange',
#   'Commission',
#   'increase',
#   'stake',
#   'stream',
#   'company',
#   'Netflix',
#   '42.8',
#   '2.1',
#   'million',
#   'share',
#   'Soros',
#   'Fund',
#   'Management',
#   'LLC',
#   'open',
#   'new',
#   'stake',
#   'Netflix',
#   'hold',
#   '50,000',
#   'share',
#   'end',
#   'March',
#   'T.',
#   'Rowe',
#   'Price',
#   'add',
#   'Facebook',
#   'share',
#   'quarter',
#   'increase',
#   'stake',
#   '19',
#   '107.9',
#   'million',
#   'share',
#   'end',
#   'quarter',
#   'Netflix',
#   'share',
#   'gain',
#   '2.7',
#   'close',
#   '$',
#   '354.99',
#   'Facebook',
#   'gain',
#   '3.1',
#   'close',
#   '$',
#   '186.27.faang',
#   'return',
#   'vogue',
#   '2019',
#   'outpace',
#   'broad',
#   'market',
#   'recovery',
#   'Netflix',
#   'surge',
#   '33',
#   'year',
#   'date',
#   'despite',
#   'slow',
#   'user',
#   'expansion',
#   'threat',
#   'Walt',
#   'Disney',
#   'Co',
#   'upcoming',
#   'video',
#   'streaming',
#   'service',
#   'Facebook',
#   'surge',
#   '40',
#   '2019',
#   'investor',
#   'bet',
#   'regulatory',
#   'threat',
#   'call',
#   'break',
#   'world',
#   'large',
#   'social',
#   'network',
#   'endanger',
#   'meteoric',
#   'growth',
#   'ad',
#   'sale',
#   'high',
#   'fly',
#   'faang',
#   'stock',
#   'come',
#   'earth',
#   'late',
#   'year',
#   'amid',
#   'fear',
#   'decade',
#   'old',
#   'bull',
#   'market',
#   'fade',
#   '“Facebook',
#   'stock',
#   'price',
#   'hammer',
#   'recent',
#   'controversy',
#   'make',
#   'attractive',
#   'return',
#   'outlook',
#   'stock',
#   'brighter',
#   'Paul',
#   'Greene',
#   'portfolio',
#   'manager',
#   'T.',
#   'Rowe',
#   'Price',
#   'Communications',
#   'Technology',
#   'Fund',
#   'Facebook',
#   'analyst',
#   'firm',
#   'write',
#   'end',
#   '2018',
#   'view',
#   'worry',
#   'surround',
#   'Facebook',
#   'discount',
#   'stock',
#   'eagerly',
#   'add',
#   'position',
#   '”(graphic',
#   'FANG',
#   'favor',
#   'tmsnrt.rs/2wkfg1u)quarterly',
#   'disclosure',
#   'hedge',
#   'fund',
#   'manager',
#   'stock',
#   'holding',
#   '13f',
#   'filing',
#   'SEC',
#   'public',
#   'way',
#   'track',
#   'manager',
#   'buy',
#   'selling',
#   'disclosure',
#   '45',
#   'day',
#   'end',
#   'quarter',
#   'reflect',
#   'current',
#   'position',
#   'Warren',
#   'Buffett',
#   'Berkshire',
#   'Hathaway',
#   'Inc',
#   'say',
#   'own',
#   '$',
#   '860.6',
#   'million',
#   'Amazon',
#   'share',
#   'end',
#   'March',
#   'billionaire',
#   'early',
#   'month',
#   'admit',
#   'have',
#   'underestimate',
#   'online',
#   'retailer',
#   'chief',
#   'executive',
#   'Jeff',
#   'Bezos',
#   'Buffett',
#   'tell',
#   'CNBC',
#   'early',
#   'Berkshire',
#   'buy',
#   'Amazon',
#   'share',
#   'time',
#   'detail',
#   'stake',
#   'Wednesday',
#   '13f',
#   'filing',
#   'reveal',
#   'Berkshire',
#   'take',
#   'stake',
#   'quarter',
#   'total',
#   '483,300',
#   'share',
#   'Buffett',
#   'tell',
#   'CNBC',
#   'Amazon',
#   'investment',
#   'portfolio',
#   'manager',
#   'Todd',
#   'Combs',
#   'Ted',
#   'Weschler',
#   'say',
#   'idiot',
#   'invest',
#   'Amazon',
#   'Amazon',
#   'share',
#   'March',
#   '29',
#   'trading',
#   'day',
#   'month',
#   'close',
#   '$',
#   '1,780.85',
#   'Wednesday',
#   'finish',
#   '$',
#   '1,871.15.reporting',
#   'Jennifer',
#   'Ablan',
#   'New',
#   'York',
#   'Noel',
#   'Randewich',
#   'San',
#   'Francisco',
#   'editing',
#   'Leslie',
#   'Adler',
#   'Matthew',
#   'LewisOur',
#   'Standards',
#   'Thomson',
#   'Reuters',
#   'Trust',
#   'Principles'],
#  ['Reuters',
#   'Staff3',
#   'Min',
#   'ReadLOS',
#   'ANGELES',
#   '28',
#   'Reuters',
#   'Netflix',
#   'Inc',
#   'say',
#   'Tuesday',
#   'rethink',
#   'film',
#   'television',
#   'production',
#   'investment',
#   'Georgia',
#   'new',
#   'law',
#   'severely',
#   'restrict',
#   'abortion',
#   'state',
#   'implement',
#   'continue',
#   'work',
#   'streaming',
#   'service',
#   'film',
#   'tv',
#   'show',
#   'like',
#   'crime',
#   'drama',
#   'Ozark',
#   'supernatural',
#   'thriller',
#   'Stranger',
#   'Things',
#   'U.S.',
#   'state',
#   'say',
#   'work',
#   'group',
#   'fight',
#   'Georgia',
#   'law',
#   'U.S.',
#   'court',
#   'major',
#   'Hollywood',
#   'producer',
#   'publicly',
#   'comment',
#   'call',
#   'industry',
#   'boycott',
#   'Georgia',
#   'hub',
#   'film',
#   'television',
#   'production',
#   '“We',
#   'woman',
#   'work',
#   'production',
#   'Georgia',
#   'right',
#   'million',
#   'severely',
#   'restrict',
#   'law',
#   'Netflix',
#   'chief',
#   'content',
#   'officer',
#   'Ted',
#   'Sarandos',
#   'say',
#   'statement',
#   '“It',
#   'work',
#   'ACLU',
#   'American',
#   'Civil',
#   'Liberties',
#   'Union',
#   'fight',
#   'court',
#   'give',
#   'legislation',
#   'implement',
#   'continue',
#   'film',
#   'support',
#   'partner',
#   'artist',
#   'choose',
#   'come',
#   'effect',
#   'rethink',
#   'entire',
#   'investment',
#   'Georgia',
#   'Sarandos',
#   'add',
#   'Georgia',
#   'republican',
#   'governor',
#   'sign',
#   'law',
#   '7',
#   'ban',
#   'abortion',
#   'doctor',
#   'detect',
#   'fetal',
#   'heartbeat',
#   'week',
#   'pregnancy',
#   'woman',
#   'know',
#   'pregnant',
#   'law',
#   'effect',
#   'January',
#   '1.georgia',
#   'state',
#   'pass',
#   'anti',
#   'abortion',
#   'legislation',
#   'year',
#   'purpose',
#   'induce',
#   'U.S.',
#   'Supreme',
#   'Court',
#   'overturn',
#   'Roe',
#   'v.',
#   'Wade',
#   '1973',
#   'landmark',
#   'case',
#   'establish',
#   'woman',
#   'right',
#   'terminate',
#   'pregnancy',
#   'Hollywood',
#   'figure',
#   'call',
#   'boycott',
#   'Georgia',
#   'say',
#   'donate',
#   'money',
#   'local',
#   'group',
#   'fight',
#   'abortion',
#   'law',
#   'Hollywood',
#   'studio',
#   'platform',
#   'comment',
#   'plan',
#   'accord',
#   'Georgia',
#   'film',
#   'office',
#   'website',
#   'Monday',
#   '38',
#   'movie',
#   'tv',
#   'show',
#   'currently',
#   'production',
#   'state',
#   'past',
#   'production',
#   'include',
#   'tv',
#   'series',
#   'walk',
#   'Dead',
#   '”the',
#   'maker',
#   'upcoming',
#   'comedy',
#   'star',
#   'Kristen',
#   'Wig',
#   'decide',
#   'week',
#   'shoot',
#   'Georgia',
#   'light',
#   'abortion',
#   'law',
#   'work',
#   'Ozark',
#   'season',
#   'begin',
#   'Georgia',
#   'early',
#   'month',
#   'star',
#   'executive',
#   'producer',
#   'Jason',
#   'Bateman',
#   'say',
#   'abortion',
#   'bill',
#   'law',
#   'work',
#   'Georgia',
#   'state',
#   'disgracefully',
#   'odd',
#   'woman',
#   'right',
#   'report',
#   'Jill',
#   'Serjeant',
#   'editing',
#   'Steve',
#   'Orlofsky)Our',
#   'Standards',
#   'Thomson',
#   'Reuters',
#   'Trust',
#   'Principles']]

# %% [markdown]
# # Sentiment

# %% [markdown]
# ### Method 1: Determine sentiment and compare with stock price (Create rule based system)

# %% [markdown]
# ### Method 2: Use pretrained model

# %% [markdown]
# # Testing
